# %% [markdown]
# # Importing The Libraries

# %%
import tensorflow as tf
import numpy as np
from sklearn import preprocessing

# %% [markdown]
# # Load the Data

# %%
data=np.loadtxt('Audiobooks_data.csv',delimiter=',')

# %%
data
# Out:
# array([[9.9400e+02, 1.6200e+03, 1.6200e+03, ..., 5.0000e+00, 9.2000e+01,
#         0.0000e+00],
#        [1.1430e+03, 2.1600e+03, 2.1600e+03, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [2.0590e+03, 2.1600e+03, 2.1600e+03, ..., 0.0000e+00, 3.8800e+02,
#         0.0000e+00],
#        ...,
#        [3.1134e+04, 2.1600e+03, 2.1600e+03, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [3.2832e+04, 1.6200e+03, 1.6200e+03, ..., 0.0000e+00, 9.0000e+01,
#         0.0000e+00],
#        [2.5100e+02, 1.6740e+03, 3.3480e+03, ..., 0.0000e+00, 0.0000e+00,
#         1.0000e+00]])

# %% [markdown]
# # Defining the variables

# %%
unscaled_inputs_all=data[:,1:-1]
targets_all=data[:,-1]

# %% [markdown]
# # Balancing the Datasets

# %%
num_one_targets= int(np.sum(targets_all))

# set a counter for targets that are 0 
zero_targets_counter=0
indices_to_remove=[]

for i in range(targets_all.shape[0]):
    if targets_all[i]== 0:
        zero_targets_counter +=1 
        if zero_targets_counter> num_one_targets:
            indices_to_remove.append(i)

# %%
indices_to_remove
# Out:
# [2873,
#  2874,
#  2875,
#  2876,
#  2877,
#  2878,
#  2880,
#  2881,
#  2883,
#  2885,
#  2886,
#  2887,
#  2888,
#  2889,
#  2890,
#  2891,
#  2892,
#  2894,
#  2896,
#  2898,
#  2899,
#  2900,
#  2901,
#  2902,
#  2903,
#  2904,
#  2905,
#  2906,
#  2907,
#  2908,
#  2909,
#  2910,
#  2911,
#  2912,
#  2915,
#  2916,
#  2917,
#  2918,
#  2919,
#  2920,
#  2922,
#  2923,
#  2924,
#  2925,
#  2926,
#  2928,
#  2929,
#  2930,
#  2931,
#  2932,
#  2933,
#  2934,
#  2936,
#  2937,
#  2938,
#  2940,
#  2941,
#  2942,
#  2943,
#  2944,
#  2945,
#  2946,
#  2947,
#  2948,
#  2950,
#  2951,
#  2953,
#  2954,
#  2955,
#  2956,
#  2957,
#  2958,
#  2959,
#  2960,
#  2961,
#  2964,
#  2965,
#  2966,
#  2967,
#  2968,
#  2969,
#  2970,
#  2971,
#  2972,
#  2974,
#  2975,
#  2976,
#  2977,
#  2978,
#  2979,
#  2980,
#  2981,
#  2982,
#  2984,
#  2985,
#  2986,
#  2988,
#  2989,
#  2990,
#  2991,
#  2992,
#  2993,
#  2994,
#  2995,
#  2996,
#  2998,
#  2999,
#  3000,
#  3001,
#  3003,
#  3004,
#  3005,
#  3006,
#  3007,
#  3008,
#  3009,
#  3010,
#  3011,
#  3012,
#  3013,
#  3014,
#  3015,
#  3016,
#  3017,
#  3018,
#  3019,
#  3021,
#  3022,
#  3023,
#  3024,
#  3026,
#  3027,
#  3028,
#  3029,
#  3030,
#  3031,
#  3032,
#  3033,
#  3034,
#  3035,
#  3036,
#  3037,
#  3038,
#  3040,
#  3041,
#  3042,
#  3043,
#  3044,
#  3045,
#  3046,
#  3047,
#  3048,
#  3049,
#  3050,
#  3051,
#  3052,
#  3053,
#  3054,
#  3055,
#  3056,
#  3057,
#  3058,
#  3059,
#  3060,
#  3062,
#  3063,
#  3064,
#  3065,
#  3066,
#  3067,
#  3068,
#  3069,
#  3070,
#  3071,
#  3073,
#  3074,
#  3075,
#  3076,
#  3077,
#  3078,
#  3079,
#  3080,
#  3081,
#  3082,
#  3083,
#  3084,
#  3085,
#  3086,
#  3087,
#  3089,
#  3090,
#  3091,
#  3092,
#  3093,
#  3094,
#  3095,
#  3096,
#  3098,
#  3099,
#  3100,
#  3102,
#  3103,
#  3105,
#  3106,
#  3108,
#  3109,
#  3110,
#  3112,
#  3113,
#  3114,
#  3115,
#  3116,
#  3118,
#  3119,
#  3121,
#  3122,
#  3128,
#  3129,
#  3130,
#  3131,
#  3132,
#  3133,
#  3134,
#  3136,
#  3137,
#  3138,
#  3139,
#  3140,
#  3143,
#  3144,
#  3145,
#  3146,
#  3147,
#  3148,
#  3150,
#  3151,
#  3152,
#  3153,
#  3154,
#  3156,
#  3157,
#  3158,
#  3159,
#  3160,
#  3161,
#  3162,
#  3164,
#  3165,
#  3166,
#  3167,
#  3169,
#  3170,
#  3172,
#  3173,
#  3174,
#  3175,
#  3176,
#  3177,
#  3178,
#  3179,
#  3180,
#  3181,
#  3183,
#  3184,
#  3185,
#  3186,
#  3187,
#  3188,
#  3190,
#  3192,
#  3193,
#  3194,
#  3195,
#  3196,
#  3197,
#  3198,
#  3199,
#  3200,
#  3202,
#  3203,
#  3204,
#  3205,
#  3206,
#  3207,
#  3208,
#  3209,
#  3210,
#  3211,
#  3212,
#  3213,
#  3214,
#  3215,
#  3216,
#  3217,
#  3219,
#  3220,
#  3221,
#  3223,
#  3224,
#  3226,
#  3228,
#  3229,
#  3230,
#  3231,
#  3232,
#  3234,
#  3235,
#  3236,
#  3237,
#  3239,
#  3240,
#  3241,
#  3242,
#  3243,
#  3244,
#  3245,
#  3246,
#  3247,
#  3248,
#  3250,
#  3251,
#  3252,
#  3253,
#  3254,
#  3255,
#  3256,
#  3257,
#  3258,
#  3259,
#  3260,
#  3261,
#  3262,
#  3263,
#  3264,
#  3265,
#  3266,
#  3267,
#  3268,
#  3269,
#  3270,
#  3271,
#  3272,
#  3273,
#  3276,
#  3278,
#  3279,
#  3280,
#  3281,
#  3282,
#  3283,
#  3284,
#  3285,
#  3286,
#  3287,
#  3288,
#  3290,
#  3291,
#  3292,
#  3293,
#  3294,
#  3295,
#  3296,
#  3297,
#  3298,
#  3299,
#  3300,
#  3301,
#  3302,
#  3303,
#  3304,
#  3305,
#  3306,
#  3307,
#  3308,
#  3309,
#  3311,
#  3312,
#  3313,
#  3314,
#  3315,
#  3316,
#  3317,
#  3318,
#  3319,
#  3321,
#  3322,
#  3323,
#  3324,
#  3325,
#  3328,
#  3329,
#  3331,
#  3332,
#  3333,
#  3334,
#  3336,
#  3337,
#  3338,
#  3339,
#  3340,
#  3342,
#  3343,
#  3345,
#  3346,
#  3347,
#  3349,
#  3350,
#  3351,
#  3352,
#  3353,
#  3354,
#  3355,
#  3356,
#  3361,
#  3362,
#  3364,
#  3366,
#  3368,
#  3369,
#  3370,
#  3371,
#  3372,
#  3373,
#  3374,
#  3376,
#  3377,
#  3378,
#  3379,
#  3381,
#  3382,
#  3386,
#  3387,
#  3390,
#  3391,
#  3392,
#  3393,
#  3394,
#  3395,
#  3396,
#  3397,
#  3398,
#  3399,
#  3400,
#  3402,
#  3403,
#  3404,
#  3406,
#  3408,
#  3409,
#  3410,
#  3411,
#  3412,
#  3413,
#  3414,
#  3415,
#  3416,
#  3417,
#  3418,
#  3419,
#  3420,
#  3421,
#  3422,
#  3425,
#  3426,
#  3427,
#  3428,
#  3429,
#  3430,
#  3431,
#  3432,
#  3433,
#  3435,
#  3437,
#  3438,
#  3439,
#  3440,
#  3441,
#  3442,
#  3444,
#  3445,
#  3446,
#  3447,
#  3448,
#  3449,
#  3450,
#  3451,
#  3452,
#  3453,
#  3454,
#  3455,
#  3457,
#  3458,
#  3459,
#  3460,
#  3461,
#  3462,
#  3463,
#  3464,
#  3465,
#  3466,
#  3467,
#  3468,
#  3469,
#  3470,
#  3471,
#  3473,
#  3476,
#  3477,
#  3478,
#  3479,
#  3480,
#  3481,
#  3482,
#  3483,
#  3484,
#  3486,
#  3487,
#  3489,
#  3490,
#  3491,
#  3492,
#  3493,
#  3494,
#  3495,
#  3496,
#  3497,
#  3498,
#  3499,
#  3500,
#  3501,
#  3502,
#  3503,
#  3504,
#  3505,
#  3507,
#  3508,
#  3509,
#  3512,
#  3513,
#  3514,
#  3515,
#  3516,
#  3517,
#  3518,
#  3520,
#  3522,
#  3524,
#  3525,
#  3526,
#  3527,
#  3528,
#  3529,
#  3530,
#  3531,
#  3532,
#  3534,
#  3535,
#  3536,
#  3537,
#  3538,
#  3539,
#  3540,
#  3541,
#  3542,
#  3543,
#  3544,
#  3545,
#  3546,
#  3547,
#  3548,
#  3549,
#  3550,
#  3551,
#  3553,
#  3554,
#  3555,
#  3556,
#  3557,
#  3559,
#  3560,
#  3561,
#  3563,
#  3565,
#  3567,
#  3568,
#  3569,
#  3570,
#  3571,
#  3572,
#  3573,
#  3574,
#  3576,
#  3577,
#  3578,
#  3579,
#  3580,
#  3581,
#  3582,
#  3584,
#  3586,
#  3587,
#  3588,
#  3589,
#  3590,
#  3591,
#  3592,
#  3594,
#  3595,
#  3596,
#  3597,
#  3598,
#  3599,
#  3600,
#  3601,
#  3602,
#  3603,
#  3604,
#  3606,
#  3607,
#  3608,
#  3609,
#  3610,
#  3611,
#  3612,
#  3613,
#  3614,
#  3615,
#  3616,
#  3617,
#  3618,
#  3619,
#  3620,
#  3621,
#  3622,
#  3623,
#  3624,
#  3625,
#  3626,
#  3627,
#  3628,
#  3629,
#  3630,
#  3631,
#  3632,
#  3634,
#  3635,
#  3636,
#  3637,
#  3638,
#  3640,
#  3642,
#  3643,
#  3644,
#  3645,
#  3646,
#  3648,
#  3649,
#  3651,
#  3652,
#  3653,
#  3655,
#  3656,
#  3658,
#  3659,
#  3660,
#  3661,
#  3662,
#  3663,
#  3664,
#  3665,
#  3666,
#  3667,
#  3669,
#  3672,
#  3673,
#  3674,
#  3675,
#  3676,
#  3679,
#  3680,
#  3682,
#  3684,
#  3685,
#  3686,
#  3687,
#  3689,
#  3690,
#  3691,
#  3692,
#  3693,
#  3694,
#  3695,
#  3696,
#  3697,
#  3698,
#  3699,
#  3700,
#  3701,
#  3703,
#  3704,
#  3705,
#  3706,
#  3707,
#  3708,
#  3712,
#  3715,
#  3716,
#  3718,
#  3719,
#  3720,
#  3721,
#  3722,
#  3724,
#  3726,
#  3727,
#  3728,
#  3729,
#  3730,
#  3731,
#  3732,
#  3733,
#  3734,
#  3735,
#  3736,
#  3740,
#  3741,
#  3742,
#  3743,
#  3744,
#  3745,
#  3746,
#  3747,
#  3748,
#  3749,
#  3750,
#  3752,
#  3753,
#  3754,
#  3756,
#  3758,
#  3759,
#  3760,
#  3761,
#  3762,
#  3763,
#  3764,
#  3766,
#  3767,
#  3768,
#  3769,
#  3770,
#  3771,
#  3773,
#  3774,
#  3775,
#  3776,
#  3777,
#  3778,
#  3779,
#  3780,
#  3781,
#  3782,
#  3784,
#  3785,
#  3786,
#  3787,
#  3788,
#  3789,
#  3790,
#  3791,
#  3792,
#  3793,
#  3794,
#  3795,
#  3796,
#  3798,
#  3799,
#  3800,
#  3802,
#  3803,
#  3805,
#  3806,
#  3807,
#  3808,
#  3809,
#  3810,
#  3811,
#  3812,
#  3813,
#  3814,
#  3815,
#  3816,
#  3817,
#  3818,
#  3819,
#  3820,
#  3822,
#  3823,
#  3824,
#  3825,
#  3826,
#  3827,
#  3828,
#  3829,
#  3831,
#  3832,
#  3833,
#  3834,
#  3837,
#  3838,
#  3839,
#  3840,
#  3841,
#  3842,
#  3844,
#  3845,
#  3846,
#  3847,
#  3848,
#  3849,
#  3850,
#  3851,
#  3852,
#  3853,
#  3854,
#  3856,
#  3857,
#  3858,
#  3859,
#  3860,
#  3861,
#  3862,
#  3863,
#  3864,
#  3866,
#  3867,
#  3868,
#  3870,
#  3871,
#  3872,
#  3873,
#  3874,
#  3875,
#  3876,
#  3877,
#  3878,
#  3879,
#  3881,
#  3882,
#  3883,
#  3884,
#  3885,
#  3886,
#  3887,
#  3888,
#  3890,
#  3891,
#  3892,
#  3893,
#  3894,
#  3895,
#  3896,
#  3897,
#  3898,
#  3899,
#  3900,
#  3901,
#  3903,
#  3904,
#  3905,
#  3906,
#  3907,
#  3908,
#  3909,
#  3910,
#  3911,
#  3912,
#  3914,
#  3915,
#  3916,
#  3918,
#  3919,
#  3920,
#  3921,
#  3922,
#  3924,
#  3925,
#  3927,
#  3928,
#  3929,
#  3930,
#  3931,
#  3932,
#  3933,
#  3935,
#  3936,
#  3937,
#  3939,
#  3940,
#  3941,
#  3942,
#  3943,
#  3944,
#  3945,
#  3946,
#  3947,
#  3948,
#  3949,
#  3950,
#  3951,
#  3953,
#  3954,
#  3955,
#  3956,
#  3958,
#  3960,
#  3961,
#  3963,
#  3964,
#  3965,
#  3966,
#  3967,
#  3968,
#  3969,
#  3970,
#  3971,
#  3973,
#  3974,
#  3975,
#  3976,
#  3977,
#  3979,
#  3980,
#  3982,
#  3983,
#  3984,
#  3985,
#  3987,
#  3988,
#  3990,
#  3991,
#  3992,
#  3993,
#  3994,
#  3995,
#  3996,
#  3997,
#  3998,
#  3999,
#  4000,
#  4001,
#  4002,
#  4003,
#  4004,
#  4005,
#  4006,
#  4007,
#  4009,
#  4011,
#  4012,
#  4013,
#  4015,
#  4016,
#  4017,
#  4019,
#  4021,
#  4022,
#  4023,
#  4024,
#  4025,
#  4026,
#  4027,
#  4029,
#  4030,
#  4031,
#  4033,
#  4034,
#  4035,
#  4036,
#  4037,
#  4038,
#  4039,
#  4041,
#  4042,
#  4043,
#  4044,
#  4045,
#  4047,
#  4048,
#  4049,
#  4050,
#  4051,
#  4052,
#  4053,
#  4054,
#  4055,
#  4056,
#  4057,
#  4058,
#  4059,
#  ...]

# %%
# Create two new variables, one that will contain the inputs, and one that will contain the targets.
# We delete all indices that we marked "to remove" in the loop above.
unscaled_inputs_equal_priors = np.delete(unscaled_inputs_all, indices_to_remove, axis=0)
targets_equal_priors = np.delete(targets_all, indices_to_remove, axis=0)

# %% [markdown]
# # Standardize the inputs

# %%
scaled_inputs=preprocessing.scale(unscaled_inputs_equal_priors)

# %% [markdown]
# # Shuffle the Data

# %%
shuffled_indices=np.arange(scaled_inputs.shape[0])
np.random.shuffle(shuffled_indices)

shuffled_inputs=scaled_inputs[shuffled_indices]
shuffled_targets= targets_equal_priors[shuffled_indices]

# %% [markdown]
# # Split the Dataset into Train,Validation and Test

# %%
# Count the total number of samples
samples_count = shuffled_inputs.shape[0]

# Count the samples in each subset, assuming we want 80-10-10 distribution of training, validation, and test.
# Naturally, the numbers are integers.
train_samples_count = int(0.8 * samples_count)
validation_samples_count = int(0.1 * samples_count)

# The 'test' dataset contains all remaining data.
test_samples_count = samples_count - train_samples_count - validation_samples_count

# %%
train_inputs = shuffled_inputs[:train_samples_count]
train_targets = shuffled_targets[:train_samples_count]

# %%
# Create variables that record the inputs and targets for validation.
# They are the next "validation_samples_count" observations, folllowing the "train_samples_count" we already assigned
validation_inputs = shuffled_inputs[train_samples_count:train_samples_count+validation_samples_count]
validation_targets = shuffled_targets[train_samples_count:train_samples_count+validation_samples_count]

# %%
# Create variables that record the inputs and targets for test.
# They are everything that is remaining.
test_inputs = shuffled_inputs[train_samples_count+validation_samples_count:]
test_targets = shuffled_targets[train_samples_count+validation_samples_count:]

# %%
# Print the number of targets that are 1s, the total number of samples, and the proportion for training, validation, and test.
print(np.sum(train_targets), train_samples_count, np.sum(train_targets) / train_samples_count)
print(np.sum(validation_targets), validation_samples_count, np.sum(validation_targets) / validation_samples_count)
print(np.sum(test_targets), test_samples_count, np.sum(test_targets) / test_samples_count)
# Out:
# 1796.0 3579 0.5018161497625034
# 218.0 447 0.48769574944071586
# 223.0 448 0.49776785714285715

# %% [markdown]
# # Save the three datasets in*.npz

# %%
np.savez('Audiobooks_data_train', inputs=train_inputs, targets=train_targets)
np.savez('Audiobooks_data_validation', inputs=validation_inputs, targets=validation_targets)
np.savez('Audiobooks_data_test', inputs=test_inputs, targets=test_targets)

# %% [markdown]
# # The Recap

# %% [markdown]
# * importing the library
# * loading the data
# * Defining unscaled inputs and targets
# * Balancing the datasets (50-50) with for loops and then deleting the rest of data
# * Shuffling the data
# * Spliting into Train,Validation and Test
# - identifying train,validation and test counts
# - identifying the input-output for train,validation and test with the respective indices
# * saving the dataset into npz- inputs and targets should be defined for all test,validation and train

# %%
npz=np.load("Audiobooks_data_train.npz")

# %%
train_inputs=npz["inputs"].astype(np.float)
train_targets=npz["targets"].astype(np.int)
# Out:
# C:\Users\arsalan\AppData\Local\Temp\ipykernel_7392\4025958694.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   train_inputs=npz["inputs"].astype(np.float)
# C:\Users\arsalan\AppData\Local\Temp\ipykernel_7392\4025958694.py:2: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   train_targets=npz["targets"].astype(np.int)

# %%
npz=np.load("Audiobooks_data_validation.npz")
validation_inputs,validation_targets=npz["inputs"].astype(np.float),npz["targets"].astype(np.int)
# Out:
# C:\Users\arsalan\AppData\Local\Temp\ipykernel_7392\1871016388.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   validation_inputs,validation_targets=npz["inputs"].astype(np.float),npz["targets"].astype(np.int)
# C:\Users\arsalan\AppData\Local\Temp\ipykernel_7392\1871016388.py:2: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   validation_inputs,validation_targets=npz["inputs"].astype(np.float),npz["targets"].astype(np.int)

# %%
npz=np.load("Audiobooks_data_test.npz")
test_inputs,test_targets=npz["inputs"].astype(np.float),npz["targets"].astype(np.int)
# Out:
# C:\Users\arsalan\AppData\Local\Temp\ipykernel_7392\2043691739.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   test_inputs,test_targets=npz["inputs"].astype(np.float),npz["targets"].astype(np.int)
# C:\Users\arsalan\AppData\Local\Temp\ipykernel_7392\2043691739.py:2: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   test_inputs,test_targets=npz["inputs"].astype(np.float),npz["targets"].astype(np.int)

# %% [markdown]
# # Model

# %%
input_size=10
output_size=2
hidden_layer_size=50

model=tf.keras.Sequential([tf.keras.layers.Dense(hidden_layer_size,activation="relu"),
                          tf.keras.layers.Dense(hidden_layer_size,activation="relu"),
                          tf.keras.layers.Dense(output_size,activation="softmax")
                          ])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

batch_size=100

max_epochs=100

early_stopping=tf.keras.callbacks.EarlyStopping(patience=2)

model.fit(train_inputs,train_targets,batch_size=batch_size,epochs=max_epochs,callbacks=[early_stopping],
          validation_data=(validation_inputs,validation_targets),verbose=2)
# Out:
# Epoch 1/100
# 36/36 - 1s - loss: 0.6437 - accuracy: 0.6021 - val_loss: 0.5763 - val_accuracy: 0.7114 - 958ms/epoch - 27ms/step
# Epoch 2/100
# 36/36 - 0s - loss: 0.5004 - accuracy: 0.7457 - val_loss: 0.4948 - val_accuracy: 0.7450 - 117ms/epoch - 3ms/step
# Epoch 3/100
# 36/36 - 0s - loss: 0.4336 - accuracy: 0.7879 - val_loss: 0.4479 - val_accuracy: 0.7606 - 135ms/epoch - 4ms/step
# Epoch 4/100
# 36/36 - 0s - loss: 0.3987 - accuracy: 0.7941 - val_loss: 0.4171 - val_accuracy: 0.7785 - 86ms/epoch - 2ms/step
# Epoch 5/100
# 36/36 - 0s - loss: 0.3795 - accuracy: 0.8033 - val_loss: 0.4005 - val_accuracy: 0.7897 - 68ms/epoch - 2ms/step
# Epoch 6/100
# 36/36 - 0s - loss: 0.3638 - accuracy: 0.8033 - val_loss: 0.3987 - val_accuracy: 0.7740 - 76ms/epoch - 2ms/step
# Epoch 7/100
# 36/36 - 0s - loss: 0.3553 - accuracy: 0.8128 - val_loss: 0.3908 - val_accuracy: 0.7785 - 100ms/epoch - 3ms/step
# Epoch 8/100
# 36/36 - 0s - loss: 0.3483 - accuracy: 0.8150 - val_loss: 0.3766 - val_accuracy: 0.8098 - 113ms/epoch - 3ms/step
# Epoch 9/100
# 36/36 - 0s - loss: 0.3421 - accuracy: 0.8192 - val_loss: 0.3729 - val_accuracy: 0.8054 - 101ms/epoch - 3ms/step
# Epoch 10/100
# 36/36 - 0s - loss: 0.3396 - accuracy: 0.8150 - val_loss: 0.3779 - val_accuracy: 0.7919 - 164ms/epoch - 5ms/step
# Epoch 11/100
# 36/36 - 0s - loss: 0.3397 - accuracy: 0.8134 - val_loss: 0.3728 - val_accuracy: 0.7942 - 126ms/epoch - 3ms/step
# Epoch 12/100
# 36/36 - 0s - loss: 0.3329 - accuracy: 0.8161 - val_loss: 0.3677 - val_accuracy: 0.7942 - 121ms/epoch - 3ms/step
# Epoch 13/100
# 36/36 - 0s - loss: 0.3315 - accuracy: 0.8206 - val_loss: 0.3639 - val_accuracy: 0.7808 - 116ms/epoch - 3ms/step
# Epoch 14/100
# 36/36 - 0s - loss: 0.3326 - accuracy: 0.8178 - val_loss: 0.3651 - val_accuracy: 0.8009 - 147ms/epoch - 4ms/step
# Epoch 15/100
# 36/36 - 0s - loss: 0.3274 - accuracy: 0.8240 - val_loss: 0.3724 - val_accuracy: 0.7830 - 65ms/epoch - 2ms/step

# %% [markdown]
# # model test

# %%
test_loss,test_accuracy=model.evaluate(test_inputs,test_targets)

print("test loss {0:0.2f}. test_accuracy{1:0.2f}% ".format(test_loss,test_accuracy*100))
# Out:
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3316 - accuracy: 0.8259
# test loss 0.33. test_accuracy82.59%
